# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/codespace/.local/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/codespace/.local/lib/python3.10/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.10/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./ott_data.csv")
df.head()
# Out:
# /tmp/ipykernel_5677/3246200533.py:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./ott_data.csv")
#     연번    조사연도   국가   분류  구분  사례수(명)  드라마(비율)  버라이어티쇼(비율)  음악(비율)  뉴스시사보도(비율)  \
# 0  1.0  2019.0   인도  국가별  전체   322.0      9.6         2.5     9.3         9.9
# 1  2.0  2019.0   터키  국가별  전체   321.0      4.4         3.1     2.8         7.8
# 2  3.0  2019.0  캐나다  국가별  전체   281.0     15.3         2.5     3.6         6.8
# 3  4.0  2019.0  헝가리  국가별  전체   223.0      5.4         0.9     9.0         2.2
# 4  5.0  2019.0   인도   성별  남성   159.0      7.5         3.1    10.7        10.1
#
#    ...  코미디(비율)  문화예술(비율)  퀴즈쇼게임쇼(비율)  토크쇼(비율)  키즈(비율)  리얼리티쇼(비율)  종교(비율)  \
# 0  ...     10.6       0.0         0.0      2.2     1.2        8.4     0.3
# 1  ...      9.0       0.0         2.5      1.2     5.9        4.0     0.6
# 2  ...     19.2       0.0         0.0      2.8     3.2        5.0     0.7
# 3  ...     14.3       0.0         0.0      1.8     0.9        4.0     0.0
# 4  ...     10.1       0.0         0.0      2.5     1.9        4.4     0.0
#
#    생활(비율)  시리즈물(비율)  기타(비율)
# 0     0.0       0.0     0.3
# 1     0.0       0.9     0.6
# 2     0.0       0.4     0.4
# 3     0.0       3.1     1.3
# 4     0.0       0.0     0.6
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65534 entries, 0 to 65533
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   연번          198 non-null    float64
#  1   조사연도        198 non-null    float64
#  2   국가          198 non-null    object
#  3   분류          198 non-null    object
#  4   구분          198 non-null    object
#  5   사례수(명)      198 non-null    float64
#  6   드라마(비율)     198 non-null    float64
#  7   버라이어티쇼(비율)  198 non-null    float64
#  8   음악(비율)      198 non-null    float64
#  9   뉴스시사보도(비율)  198 non-null    float64
#  10  교육(비율)      198 non-null    float64
#  11  영화(비율)      198 non-null    float64
#  12  스포츠(비율)     198 non-null    float64
#  13  다큐멘터리(비율)   198 non-null    float64
#  14  애니메이션(비율)   198 non-null    float64
#  15  코미디(비율)     198 non-null    float64
#  16  문화예술(비율)    198 non-null    float64
#  17  퀴즈쇼게임쇼(비율)  198 non-null    float64
#  18  토크쇼(비율)     198 non-null    float64
#  19  키즈(비율)      198 non-null    float64
#  20  리얼리티쇼(비율)   198 non-null    float64
#  21  종교(비율)      198 non-null    float64
#  22  생활(비율)      198 non-null    float64
#  23  시리즈물(비율)    198 non-null    float64
#  24  기타(비율)      198 non-null    float64
# dtypes: float64(22), object(3)
# memory usage: 12.5+ MB

# %%
df.isnull().sum()
# Out:
# 연번            65336
# 조사연도          65336
# 국가            65336
# 분류            65336
# 구분            65336
# 사례수(명)        65336
# 드라마(비율)       65336
# 버라이어티쇼(비율)    65336
# 음악(비율)        65336
# 뉴스시사보도(비율)    65336
# 교육(비율)        65336
# 영화(비율)        65336
# 스포츠(비율)       65336
# 다큐멘터리(비율)     65336
# 애니메이션(비율)     65336
# 코미디(비율)       65336
# 문화예술(비율)      65336
# 퀴즈쇼게임쇼(비율)    65336
# 토크쇼(비율)       65336
# 키즈(비율)        65336
# 리얼리티쇼(비율)     65336
# 종교(비율)        65336
# 생활(비율)        65336
# 시리즈물(비율)      65336
# 기타(비율)        65336
# dtype: int64

# %%
df.describe()
# Out:
#                연번         조사연도      사례수(명)     드라마(비율)  버라이어티쇼(비율)  \
# count  198.000000   198.000000  198.000000  198.000000  198.000000
# mean    99.500000  2019.479798  103.368687   13.861111    4.767677
# std     57.301832     0.500858   78.419349    9.458134    5.424673
# min      1.000000  2019.000000    2.000000    0.000000    0.000000
# 25%     50.250000  2019.000000   48.000000    5.900000    1.125000
# 50%     99.500000  2019.000000   76.500000   12.950000    3.100000
# 75%    148.750000  2020.000000  146.000000   19.475000    6.075000
# max    198.000000  2020.000000  373.000000   50.000000   25.000000
#
#            음악(비율)  뉴스시사보도(비율)      교육(비율)      영화(비율)     스포츠(비율)  ...  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000  ...
# mean     5.134343    7.181313    2.296970   25.929293    8.404545  ...
# std      4.389088    5.681916    2.405829   12.248769    5.425128  ...
# min      0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%      1.900000    3.700000    0.000000   18.675000    4.300000  ...
# 50%      4.400000    6.300000    1.900000   26.700000    8.450000  ...
# 75%      7.250000    9.100000    3.100000   34.975000   11.775000  ...
# max     21.700000   50.000000   15.000000   57.100000   30.800000  ...
#
#           코미디(비율)    문화예술(비율)  퀴즈쇼게임쇼(비율)     토크쇼(비율)      키즈(비율)   리얼리티쇼(비율)  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     9.115152    0.614141    0.725253    1.643434    2.256061    3.285859
# std      7.133205    1.307340    1.378430    1.914819    2.668340    3.194459
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.350000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      9.400000    0.000000    0.000000    1.250000    1.500000    2.750000
# 75%     13.300000    0.500000    1.100000    2.300000    3.400000    5.200000
# max     33.300000    6.300000    9.100000   12.500000   14.600000   12.300000
#
#            종교(비율)      생활(비율)    시리즈물(비율)      기타(비율)
# count  198.000000  198.000000  198.000000  198.000000
# mean     0.596465    0.113131    0.371717    0.253030
# std      1.211132    0.432827    0.987129    0.636429
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000
# 75%      0.775000    0.000000    0.000000    0.000000
# max      9.100000    4.200000    4.600000    3.800000
#
# [8 rows x 22 columns]

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf']

# %%
from matplotlib import font_manager, rc
font_path = '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import seaborn as sns
df = df[df['국가'] != 'Missing']
top = df['국가'].value_counts()
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.figure(figsize=(10,7))
sns.barplot(x=top.index,y=top.values)
plt.xticks(rotation=45)
plt.title('country',color = 'blue')
# Out:
# Text(0.5, 1.0, 'country')

# %%
df_modified = df.iloc[:, 15:]
corrmat = df_modified.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
sns.FacetGrid(df, hue="국가") \
   .map(plt.scatter, "드라마(비율)", "영화(비율)") \
   .add_legend()
